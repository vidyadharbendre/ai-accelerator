# %% [markdown]
# ### Gemini Usage for LLM ###
# **Library Need**
# To use the APIs provided by the Geimi platform, the library 'Google GenAI' is required.
# Ensure to have performed 'pip install google-genai'
# The API key from your Google AI account would be required to execute this code

# %%
# Import required class from Google
from google import genai
from google.genai import types
from dotenv import load_dotenv

# Initialise an client object with API key
load_dotenv ()
client = genai.Client()

# Client = genai.Client (api_key='Your API Key')

# %% [markdown]
# **Invoke for chat Completion**
# >We try Gemini to get response from LLM
# >Note the differece in terms of API

# %%
response = client.models.generate_content(
                model="gemini-2.0-flash", 
                contents="How do I learn python?"
            )
print(response.text)
# Out:
# Learning Python is a fantastic endeavor! It's a versatile language used in everything from web development to data science. Here's a structured approach to help you learn effectively:
#
# **1. Set Clear Goals:**
#
# *   **What do you want to *do* with Python?** Are you interested in:
#     *   **Web development (backend)?** (e.g., building websites, APIs)
#     *   **Data science/machine learning?** (e.g., analyzing data, building models)
#     *   **Scripting and automation?** (e.g., automating tasks on your computer)
#     *   **Game development?**
#     *   **General purpose programming?** (just learning a good language to solve problems)
#
# *   **Knowing your goal will help you focus your learning.** You won't need to learn *everything* about Python upfront. You can prioritize the areas most relevant to your interests.
#
# **2. Choose a Learning Resource:**
#
# There are tons of excellent resources. Here's a breakdown of popular options:
#
# *   **Online Courses:**
#     *   **Codecademy:** (Interactive, good for beginners, covers basic syntax and concepts)
#     *   **Coursera:** (University-level courses, often more in-depth, sometimes require payment)
#     *   **edX:** (Similar to Coursera, from universities like MIT and Harvard)
#     *   **Udemy:** (Huge variety of courses, often on sale, quality can vary, so read reviews)
#     *   **DataCamp:** (Focused on data science/data analysis with Python)
#     *   **freeCodeCamp:** (Free, project-based learning, great for building a portfolio)
#     *   **Google's Python Class:** (Good foundational material)
#     *   **Microsoft's Python for Beginners:** (Structured, good if you like Microsoft's style)
#
# *   **Interactive Tutorials:**
#     *   **LearnPython.org:** (Free, interactive tutorial)
#     *   **Real Python:** (Tutorials, articles, and courses, some free, some paid)
#
# *   **Books:**
#     *   **"Python Crash Course" by Eric Matthes:** (Excellent for beginners, project-based)
#     *   **"Automate the Boring Stuff with Python" by Al Sweigart:** (Great for learning how to automate tasks)
#     *   **"Think Python" by Allen B. Downey:** (Free online version available, more theoretical)
#     *   **"Fluent Python" by Luciano Ramalho:** (For more advanced Python developers)
#
# *   **YouTube Channels:**
#     *   **sentdex:** (Wide range of Python tutorials, from beginner to advanced)
#     *   **Corey Schafer:** (Clear and concise tutorials on various Python topics)
#     *   **freeCodeCamp.org:** (Lots of long-form courses on various subjects, including Python)
#     *   **Programming with Mosh:** (Well-structured and engaging courses)
#
# **3. Learn the Fundamentals:**
#
# *   **Variables and Data Types:** (integers, floats, strings, booleans, lists, tuples, dictionaries, sets)
# *   **Operators:** (arithmetic, comparison, logical)
# *   **Control Flow:** (if/else statements, for loops, while loops)
# *   **Functions:** (defining and calling functions, parameters, return values)
# *   **Modules and Packages:** (importing and using external libraries)
# *   **Object-Oriented Programming (OOP):** (classes, objects, inheritance, polymorphism)  (This is important, but don't get bogged down in the theory initially.  Learn the basics and come back to it.)
# *   **Error Handling:** (try/except blocks)
#
# **4. Practice Regularly (Most Important!)**
#
# *   **Do the exercises in your chosen resource.** Don't just read; *actively* code.
# *   **Write small programs.**  Think of simple tasks you can automate or solve with Python.
# *   **Work on personal projects.**  This is the best way to solidify your knowledge and build a portfolio.  Start small and gradually increase the complexity.  Examples:
#     *   **Simple calculator**
#     *   **To-do list application**
#     *   **Number guessing game**
#     *   **Web scraper (to extract data from a website)**
#     *   **Simple data analysis project (using data from a public source)**
#
# **5. Dive Deeper Based on Your Goals:**
#
# Once you have a grasp of the fundamentals, focus on the areas relevant to your goals:
#
# *   **Web Development:**
#     *   **Frameworks:**  Learn Django or Flask. Django is a full-featured framework, while Flask is a micro-framework.
#     *   **Databases:**  Learn how to connect to and interact with databases (e.g., PostgreSQL, MySQL, SQLite).
#     *   **HTML, CSS, JavaScript:**  These are essential for front-end web development.
#     *   **REST APIs:**  Learn how to build and consume APIs.
#
# *   **Data Science/Machine Learning:**
#     *   **Libraries:** Learn NumPy (for numerical computing), Pandas (for data analysis), Matplotlib and Seaborn (for data visualization), Scikit-learn (for machine learning), TensorFlow or PyTorch (for deep learning).
#     *   **Statistics and Linear Algebra:**  A good understanding of these mathematical concepts is crucial.
#     *   **Data Wrangling and Cleaning:** Learn how to prepare data for analysis.
#     *   **Machine Learning Algorithms:**  Study various algorithms (e.g., regression, classification, clustering).
#
# *   **Scripting/Automation:**
#     *   **Libraries:** Learn `os` (for interacting with the operating system), `shutil` (for file operations), `datetime` (for working with dates and times), `requests` (for making HTTP requests), `BeautifulSoup4` (for web scraping).
#     *   **Regular Expressions:**  Learn how to use regular expressions to search and manipulate text.
#
# **6. Debugging and Problem Solving:**
#
# *   **Learn how to use a debugger.**  This will help you step through your code and identify errors.
# *   **Read error messages carefully.**  They often provide clues about what went wrong.
# *   **Use Google and Stack Overflow.**  These are invaluable resources for finding solutions to common problems.
# *   **Break down complex problems into smaller, more manageable pieces.**
#
# **7. Join a Community:**
#
# *   **Online Forums:** (Stack Overflow, Reddit (r/learnpython, r/python))
# *   **Meetups:**  Look for local Python user groups.
# *   **Contribute to Open Source Projects:**  This is a great way to learn from experienced developers and improve your skills.
#
# **8. Use a Good Development Environment:**
#
# *   **Text Editors:** VS Code (recommended, free), Sublime Text, Atom
# *   **IDEs (Integrated Development Environments):** PyCharm (popular, has a free Community Edition), Spyder (good for data science)
# *   **Jupyter Notebooks:** Great for interactive coding and data exploration.
#
# **9. Stay Up-to-Date:**
#
# *   **Python is constantly evolving.** Keep up with new features and best practices by reading blogs, attending conferences, and following Python developers on social media.
#
# **Key Tips for Success:**
#
# *   **Be patient.** Learning takes time and effort. Don't get discouraged if you don't understand something right away.
# *   **Be consistent.** Try to code regularly, even if it's just for a few minutes each day.
# *   **Focus on understanding the concepts, not just memorizing syntax.**
# *   **Don't be afraid to experiment.** Try different things and see what happens.
# *   **Ask for help when you need it.**
#
# **Example Learning Path (Beginner to Web Development with Django):**
#
# 1.  **Python Fundamentals:** (Codecademy, LearnPython.org)
# 2.  **"Python Crash Course" book:** (Work through the projects)
# 3.  **Django Tutorial:** (From the official Django documentation)
# 4.  **Build a Simple Django Project:** (e.g., a blog, a to-do list app)
# 5.  **Learn HTML, CSS, and JavaScript (basics):** (Codecademy, freeCodeCamp)
# 6.  **Dive Deeper into Django:** (Advanced tutorials, books, articles)
# 7.  **Work on More Complex Django Projects:** (Build a portfolio)
#
# Remember to adjust this path based on your specific interests. Good luck, and have fun learning Python!

# %%
# There is a specific instruction given 
Instruction = "Continue the statement and make it 50 words"
# Statement  = "When Trump says Tariff, the world ..."
Statement  = "They say technology is for people, but ..."

# Invoke multiple times ...
# ?? What do we expect 
for i in range (5):
    
    response = client.models.generate_content(
                    model="gemini-2.0-flash",
                    config =types.GenerateContentConfig(
                                system_instruction=Instruction,),
                    contents =Statement
    )

    print(response.text)
# Out:
# They say technology is for people, but sometimes it feels like people are for technology. We're glued to screens, sacrificing real-world connection for digital validation and convenience. While offering incredible benefits, it's crucial we maintain control, ensuring technology serves humanity, not the other way around.
#
# They say technology is for people, but increasingly it feels like people are for technology. We're driven by algorithms, addicted to screens, and measured by metrics, losing sight of genuine connection and human-centered progress in the relentless pursuit of innovation.
#
# They say technology is for people, but often it feels like people are for technology. We're glued to screens, chasing algorithms, and measuring worth in likes. Are we truly in control, or are we becoming slaves to the very tools designed to liberate us?
#
# They say technology is for people, but increasingly, it feels like people are for technology. We're constantly adapting to its demands, prioritizing its updates, and shaping our lives around its algorithms, often losing sight of genuine human connection in the process.
#
# They say technology is for people, but increasingly, it feels like people are for technology. We adapt our lives to its rhythms, sacrifice privacy for convenience, and become consumed by its ever-present allure, blurring the line between tool and master. Are we truly benefiting, or are we being subtly reshaped?
